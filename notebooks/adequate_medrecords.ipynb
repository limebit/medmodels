# %%
from medmodels import MedRecord

data_dir = "/Users/martin.iniguez/Desktop/projects/medmodels/data/40000/"
medrecord = MedRecord.from_ron(
    data_dir + "mimic_medrecord.ron"
)

medrecord
# Out:
# ---------------------------------------------------------------------------
# Nodes Group   Count Attribute       Type         Data
# ---------------------------------------------------------------------------
# diagnoses     3365  icd_version     Continuous   min: 9
#                                                  max: 10
#                                                  mean: 9.54
# patients      9795  anchor_age      Continuous   min: 18
#                                                  max: 91
#                                                  mean: 58.72
#                     first_admission Temporal     min: 2110-01-12 22:28:00
#                                                  max: 2207-08-31 19:53:00
#                                                  mean: 2153-05-04 09:50:33
#                     gender          Categorical  Categories: F, M
# prescriptions 3239  gsn             Unstructured 1498 unique values
# procedures    725   icd_version     Continuous   min: 9
# ...

# %%
# del medrecord.node[lambda node: node.in_group("concepts"), ["concept_index"]]
# del medrecord.node[lambda node: node.in_group("patients"), ["anchor_year", "anchor_year_group", "first_admission", "dod", "number_of_windows"]]

# medrecord.remove_groups(["patients_diagnoses", "patients_prescriptions", "patients_procedures", "concepts"])
# medrecord.add_group("concept_edges")
# medrecord.add_edges_to_group("concept_edges", medrecord.edges)
# del medrecord.edge[medrecord.edges, ["time_window", "absolute_time_window", "relative_time_window", "concept_edge"]]

# from medmodels.medrecord import Schema, GroupSchema, String, AttributeType

# schema = Schema(
#     groups=
#     {
#         "patients": GroupSchema(nodes={"gender": (String(), AttributeType.Categorical)})
#     }
# )
# medrecord.schema = schema
# medrecord.to_ron(
#     data_dir + "mimic_medrecord.ron"
# )

# %%
synthetic_medrecord = MedRecord.from_ron(
   data_dir + "synthetic_medrecord.ron"
)
# del synthetic_medrecord.node[lambda node: node.in_group("patients"), ["first_admission"]]
# from medmodels.medrecord import Schema, GroupSchema, String, AttributeType

# schema = Schema(
#     groups=
#     {
#         "patients": GroupSchema(nodes={"gender": (String(), AttributeType.Categorical)})
#     }
# )
# synthetic_medrecord.schema = schema
# synthetic_medrecord.to_ron(
#     data_dir + "synthetic_medrecord.ron"
# )
synthetic_medrecord
# Out:
# ---------------------------------------------------------------------------
# Nodes Group   Count Attribute       Type         Data
# ---------------------------------------------------------------------------
# diagnoses     3365  icd_version     Continuous   min: 9
#                                                  max: 10
#                                                  mean: 9.54
# patients      7836  anchor_age      Continuous   min: 18
#                                                  max: 91
#                                                  mean: 54.82
#                     first_admission Temporal     min: 2110-01-20 00:00:00
#                                                  max: 2207-08-23 00:00:00
#                                                  mean: 2158-12-23 13:54:34
#                     gender          Categorical  Categories: F, M
# prescriptions 3239  gsn             Unstructured 1498 unique values
# procedures    725   icd_version     Continuous   min: 9
# ...
