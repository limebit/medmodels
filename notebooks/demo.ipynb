# %%
from medmodels import MedRecord
from medmodels.medrecord.querying import NodeOperand

# %%
medrecord = MedRecord.from_ron("/Users/martin.iniguez/Desktop/projects/medmodels/data/1000_medrecord.ron")
medrecord.remove_groups("concepts")

# %% [markdown]
# ## MedRecord Comparisons

# %%
# from medmodels.statistic_evaluations.evaluate_compare.evaluate import CohortEvaluator

# evaluator_medrecord = CohortEvaluator(
#    medrecord, name="MedRecord", patient_group="patients"
# )
# Out:
# Getting concept counts: 100%|██████████| 964/964 [00:16<00:00, 60.14it/s]
# Getting concept counts: 100%|██████████| 6151/6151 [01:42<00:00, 59.84it/s]
# Getting concept counts: 0it [00:00, ?it/s]
# Getting concept counts: 100%|██████████| 2508/2508 [00:42<00:00, 58.45it/s]
# Getting concept counts: 0it [00:00, ?it/s]
# Getting concept counts: 0it [00:00, ?it/s]
# Getting concept counts: 100%|██████████| 2679/2679 [00:44<00:00, 59.98it/s]

# %%
top_k_nodes = [node for node, _ in evaluator_medrecord.get_top_k_concepts(30)]
medrecord.node[top_k_nodes]
# Out:
# {'409490234': {'gsn': '001989', 'description': 'Dextrose 50%'},
#  'E785': {'description': 'Hyperlipidaemia, unspecified'},
#  '38396055018': {'description': 'Glucose Gel', 'gsn': '001781'},
#  '63323026201': {'description': 'Heparin', 'gsn': '006549'},
#  '51079000220': {'description': 'Acetaminophen', 'gsn': '004489'},
#  'K219': {'description': 'Gastro-oesophageal reflux disease without oesophagitis'},
#  '574705050': {'description': 'Bisacodyl', 'gsn': '002944'},
#  '409672924': {'description': 'Magnesium Sulfate', 'gsn': '016546'},
#  '904198861': {'gsn': '004490', 'description': 'Acetaminophen'},
#  'Z87891': {'description': None},
#  '338355248': {'description': 'Vancomycin', 'gsn': '043952'},
#  '0': {'description': '0.9% Sodium Chloride', 'gsn': None},
#  '88222033': {'gsn': '047780', 'description': 'Insulin'},
#  'I10': {'description': 'Essential (primary) hypertension'},
#  '338004938': {'gsn': '001210', 'description': '0.9% Sodium Chloride'},
#  '338011704': {'gsn': '001187', 'description': 'Lactated Ringers'},
#  '66758016013': {'gsn': '001275',
#   'description': 'Potassium Chloride Replacement (Critical Care and Oncology) '},
#  '904516561': {'description': 'Senna', 'gsn': '019964'},
#  '338004902': {'description': '0.9% Sodium Chloride', 'gsn': '001210'},
#  '409198530': {'gsn': '003753', 'description': 'Lorazepam'},
#  '338055318': {'gsn': '001210',
#   'description': '0.9% Sodium Chloride (Mini Bag Plus)'},
#  '409128331': {'gsn': '062823', 'description': 'HYDROmorphone (Dilaudid)'},
#  '904652261': {'gsn': '019964', 'description': 'Senna'},
#  '406055262': {'description': 'OxyCODONE (Immediate Release)',
#   'gsn': '004225'},
#  '904224461': {'gsn': '003009', 'description': 'Docusate Sodium'},
#  '338004903': {'gsn': '001210', 'description': '0.9% Sodium Chloride'},
#  '338004904': {'description': 'Sodium Chloride 0.9%', 'gsn': '001210'},
#  '2751001': {'gsn': '027413', 'description': 'Insulin'},
#  '51079025520': {'gsn': '050631', 'description': 'Metoprolol Tartrate'},
#  'F329': {'description': 'Depressive episode, unspecified'}}

# %%
medrecord
# Out:
# ----------------------------------------------------------------
# Nodes Group   Count Attribute   Type         Data
# ----------------------------------------------------------------
# concepts      6151  description Unstructured 1738 unique values
# concepts      6151  gsn         Unstructured 1282 unique values
# concepts      6151  icd_version Continuous   min: 9
#                                              max: 10
#                                              mean: 9.62
# diagnoses     2679  description Unstructured 889 unique values
# patients      1000  age         Continuous   min: 18
#                                              max: 91
#                                              mean: 49.13
#                     gender      Unstructured Values: F, M
# prescriptions 2508  description Unstructured 849 unique values
# prescriptions 2508  gsn         Unstructured 1282 unique values
# procedures    964   icd_version Continuous   min: 9
#                                              max: 10
#                                              mean: 9.62
# ----------------------------------------------------------------
#
# --------------------------------------------------------------------------
# Edges Group            Count Attribute Type     Data
# --------------------------------------------------------------------------
# patients_diagnoses     17084 time      Temporal min: 2110-02-10 12:41:00
#                                                 max: 2210-06-15 18:23:00
#                                                 mean: 2156-06-20 09:03:07
# patients_prescriptions 53579 time      Temporal min: 2110-02-10 12:41:00
#                                                 max: 2210-06-15 18:23:00
#                                                 mean: 2154-01-01 01:08:59
# patients_procedures    2372  time      Temporal min: 2110-07-20 07:15:00
#                                                 max: 2210-06-15 18:23:00
#                                                 mean: 2153-04-09 16:45:46
# --------------------------------------------------------------------------

# %% [markdown]
# ## MedRecord Querying

# %%
def query_young_males_with_insulin(node: NodeOperand) -> None:
    """Query that follows the following criteria:
    
    - The node must be a patient
    - The patient must be male
    - The patient must be 50 years old or younger
    - The patient must have a neighbor with the description containing the word "insulin"
    """
    node.in_group("patients")

    gender = node.attribute("gender")
    gender.lowercase()
    gender.equal_to("m")

    node.attribute("age").less_than_or_equal_to(40)

    description_neighbors = node.neighbors().attribute("description")
    description_neighbors.lowercase()
    description_neighbors.contains("insulin")


medrecord.node[query_young_males_with_insulin]
# Out:
# {16744407: {'age': 29, 'gender': 'M'},
#  10018423: {'gender': 'M', 'age': 37},
#  13479303: {'gender': 'M', 'age': 34},
#  16458055: {'age': 28, 'gender': 'M'},
#  11685402: {'age': 30, 'gender': 'M'},
#  16379286: {'gender': 'M', 'age': 34},
#  10811351: {'gender': 'M', 'age': 34},
#  17225240: {'gender': 'M', 'age': 31},
#  19638873: {'gender': 'M', 'age': 38},
#  12294267: {'gender': 'M', 'age': 38},
#  11279026: {'age': 39, 'gender': 'M'},
#  18223019: {'age': 40, 'gender': 'M'},
#  18370810: {'gender': 'M', 'age': 32},
#  18579538: {'gender': 'M', 'age': 24},
#  17733899: {'age': 35, 'gender': 'M'},
#  18284921: {'gender': 'M', 'age': 38},
#  19865076: {'gender': 'M', 'age': 31},
#  10488677: {'gender': 'M', 'age': 23},
#  10955604: {'gender': 'M', 'age': 40},
#  16624717: {'age': 40, 'gender': 'M'},
#  15837926: {'age': 28, 'gender': 'M'},
#  15792181: {'gender': 'M', 'age': 19},
#  18901587: {'gender': 'M', 'age': 36},
#  10315516: {'age': 39, 'gender': 'M'},
#  18764872: {'age': 33, 'gender': 'M'},
#  17644966: {'age': 36, 'gender': 'M'},
#  17300086: {'gender': 'M', 'age': 38},
#  19487346: {'gender': 'M', 'age': 25},
#  11646138: {'age': 38, 'gender': 'M'},
#  17197713: {'gender': 'M', 'age': 37},
#  13420572: {'age': 33, 'gender': 'M'},
#  12316990: {'age': 37, 'gender': 'M'},
#  17173309: {'gender': 'M', 'age': 39},
#  19828082: {'gender': 'M', 'age': 26},
#  10128926: {'age': 18, 'gender': 'M'},
#  14490666: {'age': 38, 'gender': 'M'},
#  16668873: {'age': 31, 'gender': 'M'}}

# %% [markdown]
# ## Calculate TreatmentEffect

# %%
medrecord.node[lambda node: node.in_group("diagnoses")]
# Out:
# {'S95909S': {'description': None},
#  'Z90410': {'description': None},
#  'G500': {'description': 'Trigeminal neuralgia'},
#  'S22078A': {'description': None},
#  'M659': {'description': 'Synovitis and tenosynovitis, unspecified'},
#  'K210': {'description': 'Gastro-oesophageal reflux disease with oesophagitis'},
#  'I7774': {'description': None},
#  'I96': {'description': None},
#  'M960': {'description': 'Pseudarthrosis after fusion or arthrodesis'},
#  'R0682': {'description': None},
#  'R32': {'description': 'Unspecified urinary incontinence'},
#  'T404X2A': {'description': None},
#  'D709': {'description': None},
#  'O3663X0': {'description': None},
#  'R631': {'description': 'Polydipsia'},
#  'Z0441': {'description': None},
#  'S60519A': {'description': None},
#  'D6861': {'description': None},
#  'D594': {'description': 'Other nonautoimmune haemolytic anaemias'},
#  'K259': {'description': 'Gastric ulcer : unspecified as acute or chronic, without haemorrhage or perforation'},
#  'D573': {'description': 'Sickle-cell trait'},
#  'E781': {'description': 'Pure hyperglyceridaemia'},
#  'S42199A': {'description': None},
#  'N3090': {'description': None},
#  'D500': {'description': 'Iron deficiency anaemia secondary to blood loss (chronic)'},
#  'Y830': {'description': 'Surgical operation with transplant of whole organ'},
#  'Y939': {'description': None},
#  'Y92488': {'description': None},
#  'D693': {'description': 'Idiopathic thrombocytopenic purpura'},
#  'O4202': {'description': None},
#  'N99521': {'description': None},
#  'C7970': {'description': None},
#  'Z9911': {'description': None},
#  'D569': {'description': 'Thalassaemia, unspecified'},
#  'S81812A': {'description': None},
#  'T40411A': {'description': None},
#  'F19921': {'description': None},
#  'J672': {'description': 'Bird fancier lung'},
#  'C781': {'description': 'Secondary malignant neoplasm of mediastinum'},
#  'G9741': {'description': None},
#  'F10239': {'description': None},
#  'V837XXA': {'description': None},
#  'M169': {'description': 'Coxarthrosis, unspecified'},
#  'H532': {'description': 'Diplopia'},
#  'N730': {'description': 'Acute parametritis and pelvic cellulitis'},
#  'I25810': {'description': None},
#  'K8070': {'description': None},
#  'F29': {'description': 'Unspecified nonorganic psychosis'},
#  'S61409A': {'description': None},
#  'I6529': {'description': None},
#  'J150': {'description': 'Pneumonia due to Klebsiella pneumoniae'},
#  'Z433': {'description': 'Attention to colostomy'},
#  'C50919': {'description': None},
#  'Y839': {'description': 'Surgical procedure, unspecified'},
#  'S60221A': {'description': None},
#  'Z85828': {'description': None},
#  'I4819': {'description': None},
#  'R402112': {'description': None},
#  'S82899A': {'description': None},
#  'L905': {'description': 'Scar conditions and fibrosis of skin'},
#  'L408': {'description': 'Other psoriasis'},
#  'S12601A': {'description': None},
#  'M79651': {'description': None},
#  'M1712': {'description': None},
#  'K652': {'description': None},
#  'R402412': {'description': None},
#  'J390': {'description': 'Retropharyngeal and parapharyngeal abscess'},
#  'C8190': {'description': None},
#  'M7071': {'description': None},
#  'M86279': {'description': None},
#  'N1832': {'description': None},
#  'D509': {'description': 'Iron deficiency anaemia, unspecified'},
#  'K7210': {'description': None},
#  'H60391': {'description': None},
#  'B999': {'description': None},
#  'M5126': {'description': None},
#  'H169': {'description': 'Keratitis, unspecified'},
#  'A86': {'description': 'Unspecified viral encephalitis'},
#  'M25559': {'description': None},
#  'C7989': {'description': None},
#  'G43109': {'description': None},
#  'R6881': {'description': None},
#  'C8339': {'description': None},
#  'F4323': {'description': None},
#  'K225': {'description': 'Diverticulum of oesophagus, acquired'},
#  'S60859A': {'description': None},
#  'G935': {'description': 'Compression of brain'},
#  'H7011': {'description': None},
#  'M4644': {'description': None},
#  'D259': {'description': 'Leiomyoma of uterus, unspecified'},
#  'R4020': {'description': None},
#  'Y836': {'description': 'Removal of other organ (partial) (total)'},
#  'I81': {'description': 'Portal vein thrombosis'},
#  'O43193': {'description': None},
#  'S2241XA': {'description': None},
#  'NoDx': {'description': None},
#  'E8351': {'description': None},
#  'K861': {'description': 'Other chronic pancreatitis'},
#  'E11622': {'description': None},
#  'E162': {'description': 'Hypoglycaemia, unspecified'},
#  'G608': {'description': 'Other hereditary and idiopathic neuropathies'},
#  'Z5112': {'description': None},
#  'I421': {'description': 'Obstructive hypertrophic cardiomyopathy'},
#  'Y834': {'description': 'Other reconstructive surgery'},
#  'M11259': {'description': None},
#  'N8353': {'description': None},
#  'M19171': {'description': None},
#  'R062': {'description': 'Wheezing'},
#  'Z1623': {'description': None},
#  'I69228': {'description': None},
#  'Y833': {'description': 'Surgical operation with formation of external stoma'},
#  'E1069': {'description': None},
#  'F4322': {'description': None},
#  'S6710XA': {'description': None},
#  'D520': {'description': 'Dietary folate deficiency anaemia'},
#  'R6510': {'description': None},
#  'C252': {'description': 'Malignant neoplasm: Tail of pancreas'},
#  'R7611': {'description': None},
#  'T801XXA': {'description': None},
#  'M2669': {'description': None},
#  'F1994': {'description': None},
#  'C20': {'description': 'Malignant neoplasm of rectum'},
#  'H6012': {'description': None},
#  'A4150': {'description': None},
#  'I700': {'description': 'Atherosclerosis of aorta'},
#  'M25521': {'description': None},
#  'I959': {'description': 'Hypotension, unspecified'},
#  'K436': {'description': 'Other and unspecified ventral hernia with obstruction without gangrene'},
#  'R1319': {'description': None},
#  'D689': {'description': 'Coagulation defect, unspecified'},
#  'I2510': {'description': None},
#  'J1289': {'description': None},
#  'C7800': {'description': None},
#  'J95851': {'description': None},
#  'J9620': {'description': None},
#  'Z808': {'description': 'Family history of malignant neoplasm of other organs or systems'},
#  'F602': {'description': 'Dissocial personality disorder'},
#  'Z3A38': {'description': None},
#  'R29701': {'description': None},
#  'G7281': {'description': None},
#  'L89132': {'description': None},
#  'M10031': {'description': None},
#  'S52026A': {'description': None},
#  'K222': {'description': 'Oesophageal obstruction'},
#  'I462': {'description': None},
#  'M8580': {'description': None},
#  'I160': {'description': None},
#  'L97428': {'description': None},
#  'T17598A': {'description': None},
#  'H9319': {'description': None},
#  'I319': {'description': 'Disease of pericardium, unspecified'},
#  'M25552': {'description': None},
#  'K7460': {'description': None},
#  'F502': {'description': 'Bulimia nervosa'},
#  'Z9641': {'description': None},
#  'J42': {'description': 'Unspecified chronic bronchitis'},
#  'D136': {'description': 'Benign neoplasm: Pancreas'},
#  'Q313': {'description': 'Laryngocele'},
#  'O411430': {'description': None},
#  'S32592A': {'description': None},
#  'R1311': {'description': None},
#  'E8770': {'description': None},
#  'S12111A': {'description': None},
#  'K5650': {'description': None},
#  'D599': {'description': 'Acquired haemolytic anaemia, unspecified'},
#  'M351': {'description': 'Other overlap syndromes'},
#  'S36899A': {'description': None},
#  'K5660': {'description': None},
#  'G932': {'description': 'Benign intracranial hypertension'},
#  'E1121': {'description': None},
#  'M4808': {'description': None},
#  'W881XXD': {'description': None},
#  'E2740': {'description': None},
#  'G9782': {'description': None},
#  'I712': {'description': 'Thoracic aortic aneurysm, without mention of rupture'},
#  'M23009': {'description': None},
#  'M1280': {'description': None},
#  'F0281': {'description': None},
#  'E1169': {'description': None},
#  'L988': {'description': 'Other specified disorders of skin and subcutaneous tissue'},
#  'T402X1A': {'description': None},
#  'I2584': {'description': None},
#  'M87059': {'description': None},
#  'S14124A': {'description': None},
#  'C258': {'description': 'Malignant neoplasm: Overlapping lesion of pancreas'},
#  'Z6834': {'description': None},
#  'S51001A': {'description': None},
#  'M961': {'description': 'Postlaminectomy syndrome, not elsewhere classified'},
#  'I602': {'description': 'Subarachnoid haemorrhage from anterior communicating artery'},
#  'T380X5A': {'description': None},
#  'I63442': {'description': None},
#  'T8612': {'description': None},
#  'K5903': {'description': None},
#  'I611': {'description': 'Intracerebral haemorrhage in hemisphere, cortical'},
#  'T829XXA': {'description': None},
#  'E113293': {'description': None},
#  'M00872': {'description': None},
#  'O42013': {'description': None},
#  'M00212': {'description': None},
#  'F19951': {'description': None},
#  'D472': {'description': 'Monoclonal gammopathy of undetermined significance (MGUS)'},
#  'R252': {'description': 'Cramp and spasm'},
#  'N939': {'description': 'Abnormal uterine and vaginal bleeding, unspecified'},
#  'C775': {'description': 'Secondary and unspecified malignant neoplasm: Intrapelvic lymph nodes'},
#  'M7981': {'description': None},
#  'R188': {'description': None},
#  'M8668': {'description': None},
#  'G4089': {'description': None},
#  'M40209': {'description': None},
#  'C251': {'description': 'Malignant neoplasm: Body of pancreas'},
#  'J679': {'description': 'Hypersensitivity pneumonitis due to unspecified organic dust'},
#  'I6203': {'description': None},
#  'Z1159': {'description': None},
#  'O321XX0': {'description': None},
#  'S32009A': {'description': None},
#  'M545': {'description': 'Low back pain'},
#  'K762': {'description': 'Central haemorrhagic necrosis of liver'},
#  'C7B09': {'description': None},
#  'Z6379': {'description': None},
#  'T184XXA': {'description': None},
#  'R45850': {'description': None},
#  'F200': {'description': 'Paranoid schizophrenia'},
#  'K2980': {'description': None},
#  'R599': {'description': 'Enlarged lymph nodes, unspecified'},
#  'T751XXA': {'description': None},
#  'Z992': {'description': 'Dependence on renal dialysis'},
#  'S335XXA': {'description': None},
#  'T426X5A': {'description': None},
#  'K264': {'description': 'Duodenal ulcer : chronic or unspecified with haemorrhage'},
#  'S0240FA': {'description': None},
#  'Z85048': {'description': None},
#  'K430': {'description': 'Incisional hernia with obstruction, without gangrene'},
#  'Z62810': {'description': None},
#  'I70209': {'description': None},
#  'Y92003': {'description': None},
#  'T8172XA': {'description': None},
#  'C8338': {'description': None},
#  'T8141XA': {'description': None},
#  'O99354': {'description': None},
#  'W5501XA': {'description': None},
#  'N393': {'description': 'Stress incontinence'},
#  'N899': {'description': 'Noninflammatory disorder of vagina, unspecified'},
#  'M00859': {'description': None},
#  'R0601': {'description': None},
#  'D6481': {'description': None},
#  'M3500': {'description': None},
#  'Z8679': {'description': None},
#  'T43634A': {'description': None},
#  'J9801': {'description': None},
#  'B9562': {'description': None},
#  'I82A21': {'description': None},
#  'K36': {'description': 'Other appendicitis'},
#  'N052': {'description': 'Unspecified nephritic syndrome : diffuse membranous glomerulonephritis'},
#  'J9811': {'description': None},
#  'Z882': {'description': 'Personal history of allergy to sulfonamides'},
#  'T8189XA': {'description': None},
#  'Z9981': {'description': None},
#  'I723': {'description': 'Aneurysm and dissection of iliac artery'},
#  'C4372': {'description': None},
#  'N179': {'description': 'Acute renal failure, unspecified'},
#  'D539': {'description': 'Nutritional anaemia, unspecified'},
#  'D61818': {'description': None},
#  'K8511': {'description': None},
#  'N130': {'description': 'Hydronephrosis with ureteropelvic junction obstruction'},
#  'K5289': {'description': None},
#  'Q278': {'description': 'Other specified congenital malformations of peripheral vascular system'},
#  'Z85840': {'description': None},
#  'Z91013': {'description': None},
#  'S51011D': {'description': None},
#  'I82599': {'description': None},
#  'O99344': {'description': None},
#  'C44329': {'description': None},
#  'O9962': {'description': None},
#  'L4059': {'description': None},
#  'E042': {'description': 'Nontoxic multinodular goitre'},
#  'B0221': {'description': None},
#  'S20312A': {'description': None},
#  'K8065': {'description': None},
#  'K625': {'description': 'Haemorrhage of anus and rectum'},
#  'M5185': {'description': None},
#  'J151': {'description': 'Pneumonia due to Pseudomonas'},
#  'W460XXA': {'description': None},
#  'R251': {'description': 'Tremor, unspecified'},
#  'B182': {'description': 'Chronic viral hepatitis C'},
#  'Z86010': {'description': None},
#  'Z89422': {'description': None},
#  'Z30430': {'description': None},
#  'O624': {'description': 'Hypertonic, incoordinate, and prolonged uterine contractions'},
#  'M10032': {'description': None},
#  'I878': {'description': 'Other specified disorders of veins'},
#  'D6489': {'description': None},
#  'G92': {'description': 'Toxic encephalopathy'},
#  'K5130': {'description': None},
#  'B20': {'description': 'Human immunodeficiency virus [HIV] disease resulting in infectious and parasitic diseases'},
#  'Z6833': {'description': None},
#  'Z9181': {'description': None},
#  'F909': {'description': 'Hyperkinetic disorder, unspecified'},
#  'H6123': {'description': None},
#  'M167': {'description': 'Other secondary coxarthrosis'},
#  'C50411': {'description': None},
#  'K760': {'description': 'Fatty (change of) liver, not elsewhere classified'},
#  'Z932': {'description': 'Ileostomy status'},
#  'F319': {'description': 'Bipolar affective disorder, unspecified'},
#  'M65811': {'description': None},
#  'S0219XA': {'description': None},
#  'L02211': {'description': None},
#  'R52': {'description': 'Pain, not elsewhere classified'},
#  'S42216A': {'description': None},
#  'M21861': {'description': None},
#  'F1111': {'description': None},
#  'R760': {'description': 'Raised antibody titre'},
#  'Y831': {'description': 'Surgical operation with implant of artificial internal device'},
#  'J690': {'description': 'Pneumonitis due to food and vomit'},
#  'C8333': {'description': None},
#  'H4921': {'description': None},
#  'A46': {'description': 'Erysipelas'},
#  'F6810': {'description': None},
#  'T462X5A': {'description': None},
#  'I25110': {'description': None},
#  'G8191': {'description': None},
#  'G939': {'description': 'Disorder of brain, unspecified'},
#  'L97419': {'description': None},
#  'J84111': {'description': None},
#  'G931': {'description': 'Anoxic brain damage, not elsewhere classified'},
#  'D3130': {'description': None},
#  'R5082': {'description': None},
#  'R809': {'description': None},
#  'T391X5A': {'description': None},
#  'C549': {'description': 'Malignant neoplasm: Corpus uteri, unspecified'},
#  'S51032A': {'description': None},
#  'E512': {'description': 'Wernicke encephalopathy'},
#  'R402312': {'description': None},
#  'K120': {'description': 'Recurrent oral aphthae'},
#  'J984': {'description': 'Other disorders of lung'},
#  'T1491XA': {'description': None},
#  'O34593': {'description': None},
#  'C029': {'description': 'Malignant neoplasm: Tongue, unspecified'},
#  'K562': {'description': 'Volvulus'},
#  'C8199': {'description': None},
#  'Z9151': {'description': None},
#  'Q7959': {'description': None},
#  'F39': {'description': 'Unspecified mood [affective] disorder'},
#  'E1039': {'description': None},
#  'S332XXA': {'description': None},
#  'C50111': {'description': None},
#  'I248': {'description': 'Other forms of acute ischaemic heart disease'},
#  'C8583': {'description': None},
#  'K7581': {'description': None},
#  'I509': {'description': 'Heart failure, unspecified'},
#  'R8281': {'description': None},
#  'L02414': {'description': None},
#  'K469': {'description': 'Unspecified abdominal hernia without obstruction or gangrene'},
#  'G40409': {'description': None},
#  'Z9351': {'description': None},
#  'N99520': {'description': None},
#  'S20212A': {'description': None},
#  'E10641': {'description': None},
#  'Z9481': {'description': None},
#  'J384': {'description': 'Oedema of larynx'},
#  'O99284': {'description': None},
#  'G519': {'description': 'Disorder of facial nerve, unspecified'},
#  'W2201XA': {'description': None},
#  'E8339': {'description': None},
#  'D89839': {'description': None},
#  'Z953': {'description': 'Presence of xenogenic heart valve'},
#  'C50419': {'description': None},
#  'Z20828': {'description': None},
#  'R402252': {'description': None},
#  'C579': {'description': 'Malignant neoplasm: Female genital organ, unspecified'},
#  'K632': {'description': 'Fistula of intestine'},
#  'T880XXA': {'description': None},
#  'J45901': {'description': None},
#  'Z6837': {'description': None},
#  'D481': {'description': 'Neoplasm of uncertain or unknown behaviour: Connective and other soft tissue'},
#  'M50222': {'description': None},
#  'K7589': {'description': None},
#  'Y92009': {'description': None},
#  'C028': {'description': 'Malignant neoplasm: Overlapping lesion of tongue'},
#  'R7401': {'description': None},
#  'Z792': {'description': None},
#  'E873': {'description': 'Alkalosis'},
#  'B349': {'description': 'Viral infection, unspecified'},
#  'H60399': {'description': None},
#  'Q600': {'description': 'Renal agenesis, unilateral'},
#  'K5710': {'description': None},
#  'R001': {'description': 'Bradycardia, unspecified'},
#  'T443X5A': {'description': None},
#  'R414': {'description': None},
#  'F0390': {'description': None},
#  'T473X5A': {'description': None},
#  'C7A8': {'description': None},
#  'Z9114': {'description': None},
#  'I120': {'description': 'Hypertensive renal disease with renal failure'},
#  'V193XXD': {'description': None},
#  'Z22321': {'description': None},
#  'F309': {'description': 'Manic episode, unspecified'},
#  'Z6823': {'description': None},
#  'I82629': {'description': None},
#  'R42': {'description': 'Dizziness and giddiness'},
#  'M62838': {'description': None},
#  'F4320': {'description': None},
#  'Z87898': {'description': None},
#  'V465XXA': {'description': None},
#  'Z955': {'description': 'Presence of coronary angioplasty implant and graft'},
#  'I6310': {'description': None},
#  'I771': {'description': 'Stricture of artery'},
#  'N2889': {'description': None},
#  'H18519': {'description': None},
#  'B9681': {'description': None},
#  'H5440': {'description': None},
#  'B181': {'description': 'Chronic viral hepatitis B without delta-agent'},
#  'I7409': {'description': None},
#  'S1091XA': {'description': None},
#  'W500XXA': {'description': None},
#  'K8071': {'description': None},
#  'I4581': {'description': None},
#  'L089': {'description': 'Local infection of skin and subcutaneous tissue, unspecified'},
#  'Z781': {'description': None},
#  'H9110': {'description': None},
#  'I82493': {'description': None},
#  'N185': {'description': 'Chronic kidney disease, stage 5'},
#  'T40605A': {'description': None},
#  'J9622': {'description': None},
#  'R7989': {'description': None},
#  'T45525A': {'description': None},
#  'I82B12': {'description': None},
#  'M00871': {'description': None},
#  'R3915': {'description': None},
#  'Y92239': {'description': None},
#  'L7682': {'description': None},
#  'C9141': {'description': None},
#  'R0683': {'description': None},
#  'K766': {'description': 'Portal hypertension'},
#  'Z8249': {'description': None},
#  'S8012XA': {'description': None},
#  'O731': {'description': 'Retained portions of placenta and membranes, without haemorrhage'},
#  'G9389': {'description': None},
#  'G518': {'description': 'Other disorders of facial nerve'},
#  'I25118': {'description': None},
#  'T424X5A': {'description': None},
#  'T84029A': {'description': None},
#  'Q230': {'description': 'Congenital stenosis of aortic valve'},
#  'J154': {'description': 'Pneumonia due to other streptococci'},
#  'T82868A': {'description': None},
#  'O3421': {'description': None},
#  'B1910': {'description': None},
#  'N739': {'description': 'Female pelvic inflammatory disease, unspecified'},
#  'L500': {'description': 'Allergic urticaria'},
#  'K91850': {'description': None},
#  'N529': {'description': None},
#  'R402142': {'description': None},
#  'N12': {'description': 'Tubulo-interstitial nephritis, not specified as acute or chronic'},
#  'Z96642': {'description': None},
#  'M19071': {'description': None},
#  'I610': {'description': 'Intracerebral haemorrhage in hemisphere, subcortical'},
#  'S0010XA': {'description': None},
#  'C7801': {'description': None},
#  'A071': {'description': 'Giardiasis [lambliasis]'},
#  'L84': {'description': 'Corns and callosities'},
#  'R3914': {'description': None},
#  'M24662': {'description': None},
#  'M9712XA': {'description': None},
#  'K859': {'description': 'Acute pancreatitis, unspecified'},
#  'J449': {'description': 'Chronic obstructive pulmonary disease, unspecified'},
#  'O9903': {'description': None},
#  'F312': {'description': 'Bipolar affective disorder, current episode manic with psychotic symptoms'},
#  'K7290': {'description': None},
#  'N5089': {'description': None},
#  'M00061': {'description': None},
#  'Y838': {'description': 'Other surgical procedures'},
#  'O09513': {'description': None},
#  'W03XXXA': {'description': None},
#  'M5002': {'description': None},
#  'J4540': {'description': None},
#  'I4820': {'description': None},
#  'S52272A': {'description': None},
#  'M25511': {'description': None},
#  'I6522': {'description': None},
#  'T50995A': {'description': None},
#  'T827XXA': {'description': None},
#  'Z8589': {'description': None},
#  'T80211A': {'description': None},
#  'I318': {'description': 'Other specified diseases of pericardium'},
#  'Z87311': {'description': None},
#  'K91840': {'description': None},
#  'G911': {'description': 'Obstructive hydrocephalus'},
#  'Z9849': {'description': None},
#  'S2243XA': {'description': None},
#  'Y92000': {'description': None},
#  'I213': {'description': 'Acute transmural myocardial infarction of unspecified site'},
#  'K661': {'description': 'Haemoperitoneum'},
#  'E10319': {'description': None},
#  'M940': {'description': 'Chondrocostal junction syndrome [Tietze]'},
#  'Z85118': {'description': None},
#  'R9439': {'description': None},
#  'I5041': {'description': None},
#  'S3590XA': {'description': None},
#  'E7800': {'description': None},
#  'M86171': {'description': None},
#  'F1113': {'description': None},
#  'I69319': {'description': None},
#  'K644': {'description': 'Residual haemorrhoidal skin tags'},
#  'R208': {'description': 'Other and unspecified disturbances of skin sensation'},
#  'I4949': {'description': None},
#  'Z2889': {'description': None},
#  'C8389': {'description': None},
#  'R300': {'description': 'Dysuria'},
#  'N840': {'description': 'Polyp of corpus uteri'},
#  'I5032': {'description': None},
#  'O6014X0': {'description': None},
#  'Z9282': {'description': None},
#  'M952': {'description': 'Other acquired deformity of head'},
#  'F3110': {'description': None},
#  'M79609': {'description': None},
#  'W19XXXA': {'description': None},
#  'T471X4A': {'description': None},
#  'J440': {'description': 'Chronic obstructive pulmonary disease with acute lower respiratory infection'},
#  'M4854XA': {'description': None},
#  'H9190': {'description': None},
#  'L298': {'description': 'Other pruritus'},
#  'E8352': {'description': None},
#  'I639': {'description': 'Cerebral infarction, unspecified'},
#  'Y828': {'description': 'Other and unspecified medical devices associated with adverse incidents : miscellaneous devices, not elsewhere classified'},
#  'M4714': {'description': None},
#  'K1379': {'description': None},
#  'F3289': {'description': None},
#  'Z7902': {'description': None},
#  'G252': {'description': 'Other specified forms of tremor'},
#  'G40109': {'description': None},
#  'R279': {'description': None},
#  'J069': {'description': 'Acute upper respiratory infection, unspecified'},
#  'Z3A41': {'description': None},
#  'Z8501': {'description': None},
#  'S40811A': {'description': None},
#  'Y92099': {'description': None},
#  'F430': {'description': 'Acute stress reaction'},
#  'I513': {'description': 'Intracardiac thrombosis, not elsewhere classified'},
#  'O4212': {'description': None},
#  'L304': {'description': 'Erythema intertrigo'},
#  'C8590': {'description': None},
#  'Z62819': {'description': None},
#  'G44009': {'description': None},
#  'Z8507': {'description': None},
#  'D65': {'description': 'Disseminated intravascular coagulation [defibrination syndrome]'},
#  'T65894A': {'description': None},
#  'H43393': {'description': None},
#  'H6690': {'description': None},
#  'Z8553': {'description': None},
#  'F323': {'description': 'Severe depressive episode with psychotic symptoms'},
#  'F1123': {'description': None},
#  'E8359': {'description': None},
#  'I272': {'description': 'Other secondary pulmonary hypertension'},
#  'N50819': {'description': None},
#  'R180': {'description': None},
#  'Z881': {'description': 'Personal history of allergy to other antibiotic agents'},
#  'J15211': {'description': None},
#  'I5030': {'description': None},
#  'I7300': {'description': None},
#  'T783XXA': {'description': None},
#  'M25512': {'description': None},
#  'S161XXA': {'description': None},
#  'M5416': {'description': None},
#  'T8579XA': {'description': None},
#  'E1010': {'description': None},
#  'J948': {'description': 'Other specified pleural conditions'},
#  'G809': {'description': 'Cerebral palsy, unspecified'},
#  'K613': {'description': 'Ischiorectal abscess'},
#  'I9789': {'description': None},
#  'Z22330': {'description': None},
#  'Z85528': {'description': None},
#  'S0292XA': {'description': None},
#  'M722': {'description': 'Plantar fascial fibromatosis'},
#  'E2749': {'description': None},
#  'C259': {'description': 'Malignant neoplasm: Pancreas, unspecified'},
#  'C3410': {'description': None},
#  'I2542': {'description': None},
#  'M4636': {'description': None},
#  'W1830XA': {'description': None},
#  'B0222': {'description': None},
#  'W1830XD': {'description': None},
#  'N61': {'description': 'Inflammatory disorders of breast'},
#  'Z6845': {'description': None},
#  'I119': {'description': 'Hypertensive heart disease without (congestive) heart failure'},
#  'L299': {'description': 'Pruritus, unspecified'},
#  'C3411': {'description': None},
#  'I6521': {'description': None},
#  'Q409': {'description': 'Congenital malformation of upper alimentary tract, unspecified'},
#  'R109': {'description': None},
#  'E079': {'description': 'Disorder of thyroid, unspecified'},
#  'R1909': {'description': None},
#  'I82819': {'description': None},
#  'G8190': {'description': None},
#  'E875': {'description': 'Hyperkalaemia'},
#  'J0100': {'description': None},
#  'I890': {'description': 'Lymphoedema, not elsewhere classified'},
#  'E236': {'description': 'Other disorders of pituitary gland'},
#  'K9419': {'description': None},
#  'L02214': {'description': None},
#  'R748': {'description': 'Abnormal levels of other serum enzymes'},
#  'I7101': {'description': None},
#  'S64496A': {'description': None},
#  'Z8547': {'description': None},
#  'N3289': {'description': None},
#  'Y840': {'description': 'Cardiac catheterization'},
#  'N186': {'description': None},
#  'R29716': {'description': None},
#  'Z765': {'description': 'Malingerer [conscious simulation]'},
#  'C9250': {'description': None},
#  'L03112': {'description': None},
#  'D7582': {'description': None},
#  'D279': {'description': None},
#  'L03031': {'description': None},
#  'R1310': {'description': None},
#  'B9689': {'description': None},
#  'A020': {'description': 'Salmonella enteritis'},
#  'K3589': {'description': None},
#  'V899XXS': {'description': None},
#  'D473': {'description': 'Essential (haemorrhagic) thrombocythaemia'},
#  'T814XXA': {'description': None},
#  'S8010XA': {'description': None},
#  'T50905A': {'description': None},
#  'S43429A': {'description': None},
#  'Z833': {'description': 'Family history of diabetes mellitus'},
#  'Y792': {'description': 'Orthopaedic devices associated with adverse incidents : prosthetic and other implants, materials and accessory devices'},
#  'C7951': {'description': None},
#  'G540': {'description': 'Brachial plexus disorders'},
#  'N400': {'description': None},
#  'T8351XA': {'description': None},
#  'I83009': {'description': None},
#  'M9080': {'description': None},
#  'E041': {'description': 'Nontoxic single thyroid nodule'},
#  'J36': {'description': 'Peritonsillar abscess'},
#  'Z7952': {'description': None},
#  'M24562': {'description': None},
#  'B351': {'description': 'Tinea unguium'},
#  'O9963': {'description': None},
#  'I868': {'description': 'Varicose veins of other specified sites'},
#  'S02600A': {'description': None},
#  'D151': {'description': 'Benign neoplasm: Heart'},
#  'K2960': {'description': None},
#  'L03129': {'description': None},
#  'K5720': {'description': None},
#  'I69928': {'description': None},
#  'R1033': {'description': None},
#  'S60419A': {'description': None},
#  'S42031A': {'description': None},
#  'E612': {'description': 'Magnesium deficiency'},
#  'E40': {'description': 'Kwashiorkor'},
#  'J129': {'description': 'Viral pneumonia, unspecified'},
#  'R45851': {'description': None},
#  'G90519': {'description': None},
#  'G312': {'description': 'Degeneration of nervous system due to alcohol'},
#  'C778': {'description': 'Secondary and unspecified malignant neoplasm: Lymph nodes of multiple regions'},
#  'A310': {'description': 'Pulmonary mycobacterial infection'},
#  'C8194': {'description': None},
#  'Y92238': {'description': None},
#  'M75101': {'description': None},
#  'R338': {'description': None},
#  'S01512A': {'description': None},
#  'K631': {'description': 'Perforation of intestine (nontraumatic)'},
#  'I2119': {'description': None},
#  'M5410': {'description': None},
#  'T391X4A': {'description': None},
#  'S61509A': {'description': None},
#  'S32011A': {'description': None},
#  'O9081': {'description': None},
#  'S270XXA': {'description': None},
#  'S3600XA': {'description': None},
#  'F17210': {'description': None},
#  'O6003': {'description': None},
#  'E11649': {'description': None},
#  'G9589': {'description': None},
#  'S12090A': {'description': None},
#  'Y92410': {'description': None},
#  'G63': {'description': 'Polyneuropathy in diseases classified elsewhere'},
#  'K810': {'description': 'Acute cholecystitis'},
#  'J309': {'description': None},
#  'Z7901': {'description': None},
#  'I5031': {'description': None},
#  'D682': {'description': 'Hereditary deficiency of other clotting factors'},
#  'Z915': {'description': 'Personal history of self-harm'},
#  'Z952': {'description': 'Presence of prosthetic heart valve'},
#  'S060X1A': {'description': None},
#  'R200': {'description': 'Anaesthesia of skin'},
#  'A5909': {'description': None},
#  'R002': {'description': 'Palpitations'},
#  'C801': {'description': None},
#  'C7889': {'description': None},
#  'Z9111': {'description': None},
#  'I82B21': {'description': None},
#  'Z1509': {'description': None},
#  'M25571': {'description': None},
#  'F603': {'description': 'Emotionally unstable personality disorder'},
#  'E7439': {'description': None},
#  'S82846A': {'description': None},
#  'I672': {'description': 'Cerebral atherosclerosis'},
#  'C609': {'description': 'Malignant neoplasm: Penis, unspecified'},
#  'F1990': {'description': None},
#  'I38': {'description': 'Endocarditis, valve unspecified'},
#  'O9952': {'description': None},
#  'S61209A': {'description': None},
#  'T8183XA': {'description': None},
#  'B961': {'description': 'Klebsiella pneumoniae [K. pneumoniae] as the cause of diseases classified to other chapters'},
#  'B029': {'description': 'Zoster without complication'},
#  'S52539A': {'description': None},
#  'I714': {'description': 'Abdominal aortic aneurysm, without mention of rupture'},
#  'I8510': {'description': None},
#  'I8001': {'description': None},
#  'Z96659': {'description': None},
#  'H748X9': {'description': None},
#  'F17200': {'description': None},
#  'O324XX0': {'description': None},
#  'J82': {'description': 'Pulmonary eosinophilia, not elsewhere classified'},
#  'Z8781': {'description': None},
#  'F1190': {'description': None},
#  'V299XXA': {'description': None},
#  'K635': {'description': 'Polyp of colon'},
#  'R29898': {'description': None},
#  'L89152': {'description': None},
#  'M19032': {'description': None},
#  'Z0389': {'description': None},
#  'F1011': {'description': None},
#  'K029': {'description': 'Dental caries, unspecified'},
#  'R400': {'description': 'Somnolence'},
#  'R209': {'description': None},
#  'K7030': {'description': None},
#  'I82431': {'description': None},
#  'S82202K': {'description': None},
#  'Z96611': {'description': None},
#  'N719': {'description': 'Inflammatory disease of uterus, unspecified'},
#  'T368X5A': {'description': None},
#  'L270': {'description': 'Generalized skin eruption due to drugs and medicaments'},
#  'E43': {'description': 'Unspecified severe protein-energy malnutrition'},
#  'K589': {'description': None},
#  'E1143': {'description': None},
#  'R8271': {'description': None},
#  'O701': {'description': 'Second degree perineal laceration during delivery'},
#  'K2970': {'description': None},
#  'Y92511': {'description': None},
#  'M4622': {'description': None},
#  'R1312': {'description': None},
#  'R443': {'description': 'Hallucinations, unspecified'},
#  'R490': {'description': 'Dysphonia'},
#  'O660': {'description': 'Obstructed labour due to shoulder dystocia'},
#  'I492': {'description': 'Junctional premature depolarization'},
#  'I82C29': {'description': None},
#  'C3481': {'description': None},
#  'D7389': {'description': None},
#  'N2581': {'description': None},
#  'C7A098': {'description': None},
#  'M86671': {'description': None},
#  'G4733': {'description': None},
#  'I5020': {'description': None},
#  'I7092': {'description': None},
#  'M6281': {'description': None},
#  'R351': {'description': None},
#  'R9401': {'description': None},
#  'A049': {'description': 'Bacterial intestinal infection, unspecified'},
#  'B3789': {'description': None},
#  'I63411': {'description': None},
#  'Z6820': {'description': None},
#  'W458XXA': {'description': None},
#  'H832X9': {'description': None},
#  'I82B29': {'description': None},
#  'O360930': {'description': None},
#  'B159': {'description': 'Hepatitis A without hepatic coma'},
#  'I352': {'description': 'Aortic (valve) stenosis with insufficiency'},
#  'E11621': {'description': None},
#  'C7A012': {'description': None},
#  'R456': {'description': 'Physical violence'},
#  'H02106': {'description': None},
#  'O9852': {'description': None},
#  'J989': {'description': 'Respiratory disorder, unspecified'},
#  'G510': {'description': 'Bell palsy'},
#  'M47816': {'description': None},
#  'Z91128': {'description': None},
#  'Z791': {'description': None},
#  'E561': {'description': 'Deficiency of vitamin K'},
#  'M25569': {'description': None},
#  'C7650': {'description': None},
#  'R4189': {'description': None},
#  'Z7682': {'description': None},
#  'I6202': {'description': None},
#  'G9619': {'description': None},
#  'R632': {'description': 'Polyphagia'},
#  'L271': {'description': 'Localized skin eruption due to drugs and medicaments'},
#  'I5189': {'description': None},
#  'E8809': {'description': None},
#  'H6691': {'description': None},
#  'K219': {'description': 'Gastro-oesophageal reflux disease without oesophagitis'},
#  'E611': {'description': 'Iron deficiency'},
#  'O620': {'description': 'Primary inadequate contractions'},
#  'I361': {'description': 'Nonrheumatic tricuspid (valve) insufficiency'},
#  'K754': {'description': 'Autoimmune hepatitis'},
#  'I6783': {'description': None},
#  'M064': {'description': 'Inflammatory polyarthropathy'},
#  'C61': {'description': 'Malignant neoplasm of prostate'},
#  'S0993XA': {'description': None},
#  'N9419': {'description': None},
#  'M4010': {'description': None},
#  'I82522': {'description': None},
#  'Z7401': {'description': None},
#  'I078': {'description': 'Other tricuspid valve diseases'},
#  'F509': {'description': 'Eating disorder, unspecified'},
#  'B3783': {'description': None},
#  'H3400': {'description': None},
#  'K8030': {'description': None},
#  'Z6841': {'description': None},
#  'S82142A': {'description': None},
#  'R569': {'description': None},
#  'K30': {'description': 'Functional dyspepsia'},
#  'F4481': {'description': None},
#  'T447X5A': {'description': None},
#  'R29810': {'description': None},
#  'I348': {'description': 'Other nonrheumatic mitral valve disorders'},
#  'I4430': {'description': None},
#  'I69959': {'description': None},
#  'I619': {'description': 'Intracerebral haemorrhage, unspecified'},
#  'F429': {'description': 'Obsessive-compulsive disorder, unspecified'},
#  'L03113': {'description': None},
#  'L249': {'description': 'Irritant contact dermatitis, unspecified cause'},
#  'R4701': {'description': None},
#  'N8111': {'description': None},
#  'N471': {'description': None},
#  'R4182': {'description': None},
#  'C8280': {'description': None},
#  'Z8571': {'description': None},
#  'K8012': {'description': None},
#  'Z7982': {'description': None},
#  'R0602': {'description': None},
#  'I82492': {'description': None},
#  'L0231': {'description': None},
#  'I480': {'description': 'Paroxysmal atrial fibrillation'},
#  'Z89512': {'description': None},
#  'I824Y9': {'description': None},
#  'N993': {'description': 'Prolapse of vaginal vault after hysterectomy'},
#  'F609': {'description': 'Personality disorder, unspecified'},
#  'Z940': {'description': 'Kidney transplant status'},
#  'E878': {'description': 'Other disorders of electrolyte and fluid balance, not elsewhere classified'},
#  'O692XX0': {'description': None},
#  'G508': {'description': 'Other disorders of trigeminal nerve'},
#  'T361X5A': {'description': None},
#  'F5000': {'description': None},
#  'E896': {'description': 'Postprocedural adrenocortical(-medullary) hypofunction'},
#  'D72829': {'description': None},
#  'K8681': {'description': None},
#  'R911': {'description': None},
#  'J918': {'description': None},
#  'J3489': {'description': None},
#  'R630': {'description': 'Anorexia'},
#  'E869': {'description': None},
#  'N7093': {'description': None},
#  'Z9483': {'description': None},
#  'K5651': {'description': None},
#  'K709': {'description': 'Alcoholic liver disease, unspecified'},
#  'M65849': {'description': None},
#  'E10610': {'description': None},
#  'Z89519': {'description': None},
#  'I82432': {'description': None},
#  'S14127A': {'description': None},
#  'E1129': {'description': None},
#  'M179': {'description': 'Gonarthrosis, unspecified'},
#  'K5790': {'description': None},
#  'O411230': {'description': None},
#  'I671': {'description': 'Cerebral aneurysm, nonruptured'},
#  'I82A12': {'description': None},
#  'G8918': {'description': None},
#  'Z6843': {'description': None},
#  'N920': {'description': 'Excessive and frequent menstruation with regular cycle'},
#  'Z472': {'description': None},
#  'N39498': {'description': None},
#  'Z811': {'description': 'Family history of alcohol abuse'},
#  'C7931': {'description': None},
#  'Z86008': {'description': None},
#  'T50906A': {'description': None},
#  'K381': {'description': 'Appendicular concretions'},
#  'I6052': {'description': None},
#  'Z96651': {'description': None},
#  'D721': {'description': 'Eosinophilia'},
#  'H548': {'description': None},
#  'G9529': {'description': None},
#  'L251': {'description': 'Unspecified contact dermatitis due to drugs in contact with skin'},
#  'I4821': {'description': None},
#  'M79661': {'description': None},
#  'S06360S': {'description': None},
#  'S22081A': {'description': None},
#  'M9250': {'description': None},
#  'S42291A': {'description': None},
#  'K439': {'description': 'Other and unspecified ventral hernia without obstruction or gangrene'},
#  'Y844': {'description': 'Aspiration of fluid'},
#  'M170': {'description': 'Primary gonarthrosis, bilateral'},
#  'J40': {'description': 'Bronchitis, not specified as acute or chronic'},
#  'F1120': {'description': None},
#  'Z98890': {'description': None},
#  'K315': {'description': 'Obstruction of duodenum'},
#  'G3183': {'description': None},
#  'E860': {'description': None},
#  'J431': {'description': 'Panlobular emphysema'},
#  'K633': {'description': 'Ulcer of intestine'},
#  'D892': {'description': 'Hypergammaglobulinaemia, unspecified'},
#  'G1221': {'description': None},
#  'M419': {'description': 'Scoliosis, unspecified'},
#  'A879': {'description': 'Viral meningitis, unspecified'},
#  'R0689': {'description': None},
#  'T43294A': {'description': None},
#  'R471': {'description': 'Dysarthria and anarthria'},
#  'K0511': {'description': None},
#  'I69351': {'description': None},
#  'D869': {'description': 'Sarcoidosis, unspecified'},
#  'J386': {'description': 'Stenosis of larynx'},
#  'K5649': {'description': None},
#  'S36031A': {'description': None},
#  'B2790': {'description': None},
#  'E119': {'description': 'Type 2 diabetes mellitus without complications'},
#  'R739': {'description': 'Hyperglycaemia, unspecified'},
#  'G4752': {'description': None},
#  'W06XXXA': {'description': None},
#  'B372': {'description': 'Candidiasis of skin and nail'},
#  'W19XXXS': {'description': None},
#  'J95812': {'description': None},
#  'N184': {'description': 'Chronic kidney disease, stage 4'},
#  'S66124A': {'description': None},
#  'M25579': {'description': None},
#  'O9989': {'description': None},
#  'I200': {'description': 'Unstable angina'},
#  'R509': {'description': 'Fever, unspecified'},
#  'Y846': {'description': 'Urinary catheterization'},
#  'A6000': {'description': None},
#  'I776': {'description': 'Arteritis, unspecified'},
#  'D508': {'description': 'Other iron deficiency anaemias'},
#  'Z8379': {'description': None},
#  'Z45018': {'description': None},
#  'E139': {'description': 'Other specified diabetes mellitus without complications'},
#  'D487': {'description': 'Neoplasm of uncertain or unknown behaviour: Other specified sites'},
#  'Z930': {'description': 'Tracheostomy status'},
#  'T7802XA': {'description': None},
#  'M87852': {'description': None},
#  'E1021': {'description': None},
#  'Z3A28': {'description': None},
#  'E213': {'description': 'Hyperparathyroidism, unspecified'},
#  'D351': {'description': 'Benign neoplasm: Parathyroid gland'},
#  'Z6831': {'description': None},
#  'M4856XA': {'description': None},
#  'E1342': {'description': None},
#  'K4090': {'description': None},
#  'N136': {'description': 'Pyonephrosis'},
#  'L538': {'description': 'Other specified erythematous conditions'},
#  'G4730': {'description': None},
#  'D563': {'description': 'Thalassaemia trait'},
#  'J9621': {'description': None},
#  'K380': {'description': 'Hyperplasia of appendix'},
#  'D251': {'description': 'Intramural leiomyoma of uterus'},
#  'B028': {'description': 'Zoster with other complications'},
#  'Z933': {'description': 'Colostomy status'},
#  'R161': {'description': 'Splenomegaly, not elsewhere classified'},
#  'S40819A': {'description': None},
#  'H9193': {'description': None},
#  'S1093XA': {'description': None},
#  'E782': {'description': 'Mixed hyperlipidaemia'},
#  'M48061': {'description': None},
#  'O721': {'description': 'Other immediate postpartum haemorrhage'},
#  'G893': {'description': None},
#  'R34': {'description': 'Anuria and oliguria'},
#  'R260': {'description': 'Ataxic gait'},
#  'I088': {'description': 'Other multiple valve diseases'},
#  'M6282': {'description': None},
#  'Z8572': {'description': None},
#  'G8100': {'description': None},
#  'E209': {'description': 'Hypoparathyroidism, unspecified'},
#  'G40209': {'description': None},
#  'Z6741': {'description': None},
#  'I658': {'description': 'Occlusion and stenosis of other precerebral artery'},
#  'M40202': {'description': None},
#  'R29705': {'description': None},
#  'Z2239': {'description': None},
#  'W182XXA': {'description': None},
#  'E1140': {'description': None},
#  'D702': {'description': None},
#  'Z85850': {'description': None},
#  'G9341': {'description': None},
#  'H53469': {'description': None},
#  'S065X2A': {'description': None},
#  'K921': {'description': 'Melaena'},
#  'E7849': {'description': None},
#  'M4624': {'description': None},
#  'J95811': {'description': None},
#  'R310': {'description': None},
#  'T84038A': {'description': None},
#  'D72828': {'description': None},
#  'Z8341': {'description': None},
#  'Y9301': {'description': None},
#  'T888XXA': {'description': None},
#  'I70244': {'description': None},
#  'Y9289': {'description': None},
#  'J121': {'description': 'Respiratory syncytial virus pneumonia'},
#  'J869': {'description': 'Pyothorax without fistula'},
#  'Z21': {'description': 'Asymptomatic human immunodeficiency virus [HIV] infection status'},
#  'K900': {'description': 'Coeliac disease'},
#  'C9200': {'description': None},
#  'C249': {'description': 'Malignant neoplasm: Biliary tract, unspecified'},
#  ...}

# %%
from medmodels.treatment_effect import TreatmentEffect
treatment = "saline"
outcome = "dehydration"
def query_insulin_nodes(node: NodeOperand) -> None:
    description_nodes = node.attribute("description")
    description_nodes.lowercase()
    description_nodes.contains(treatment)

def query_diabetes_nodes(node: NodeOperand) -> None:
    description_nodes = node.attribute("description")
    description_nodes.lowercase()
    description_nodes.contains(outcome)

medrecord.add_group(group=treatment, nodes=query_insulin_nodes)
medrecord.add_group(group=outcome, nodes=query_diabetes_nodes)

# %%
treatment_effect = (
    TreatmentEffect.builder()
    .with_treatment(treatment)
    .with_outcome(outcome)
    .with_patients_group("patients")
    .with_time_attribute("time")
    # .with_follow_up_period(days=365*100)
    # .with_grace_period(days=1)
    .build()
)

# %%
contingency_table = treatment_effect.estimate.subject_counts(medrecord)
print(contingency_table)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 contingency_table = treatment_effect.estimate.subject_counts(medrecord)
#       2 print(contingency_table)
#
# File ~/Desktop/projects/medmodels/medmodels/treatment_effect/estimate.py:319, in Estimate.subject_counts(self, medrecord)
#     300 def subject_counts(self, medrecord: MedRecord) -> ContingencyTable:
#     301     """Overview of how many subjects are in which group from the contingency table.
#     302
#     303     Returns a contingency table object with the number of subjects in the treatment
#    (...)    312             outcome.
#     313     """
#     314     (
#     315         number_treated_outcome_true,
#     316         number_treated_outcome_false,
#     317         number_control_outcome_true,
#     318         number_control_outcome_false,
# --> 319     ) = self._compute_subject_counts(medrecord=medrecord)
#     321     return ContingencyTable(
#     322         number_treated_outcome_true=number_treated_outcome_true,
#     323         number_treated_outcome_false=number_treated_outcome_false,
#     324         number_control_outcome_true=number_control_outcome_true,
#     325         number_control_outcome_false=number_control_outcome_false,
#     326     )
#
# File ~/Desktop/projects/medmodels/medmodels/treatment_effect/estimate.py:251, in Estimate._compute_subject_counts(self, medrecord)
#     226 def _compute_subject_counts(
#     227     self, medrecord: MedRecord
#     228 ) -> Tuple[int, int, int, int]:
#     229     """Computes the subject counts for the treatment and control groups.
#     230
#     231     Args:
#    (...)    244             zero errors.
#     245     """
#     246     (
#     247         treated_outcome_true,
#     248         treated_outcome_false,
#     249         control_outcome_true,
#     250         control_outcome_false,
# --> 251     ) = self._sort_subjects_in_groups(medrecord=medrecord)
#     253     if len(treated_outcome_false) == 0:
#     254         msg = "No subjects found in the group of treated with no outcome"
#
# File ~/Desktop/projects/medmodels/medmodels/treatment_effect/estimate.py:185, in Estimate._sort_subjects_in_groups(self, medrecord)
#     163 """Sorts subjects into the different groups of the contingency table.
#     164
#     165 This means, sorting the subjects into treatment-outcome, treatment-no outcome,
#    (...)    177         groups, respectively.
#     178 """
#     179 self._check_medrecord(medrecord=medrecord)
#     180 (
#     181     treated_outcome_true,
#     182     treated_outcome_false,
#     183     control_outcome_true,
#     184     control_outcome_false,
# --> 185 ) = self._treatment_effect._find_groups(medrecord)
#     186 treated_set = treated_outcome_true | treated_outcome_false
#     188 if self._treatment_effect._matching_method:
#
# File ~/Desktop/projects/medmodels/medmodels/treatment_effect/treatment_effect.py:264, in TreatmentEffect._find_groups(self, medrecord)
#     260 else:
#     261     washout_nodes = set()
#     263 treated_set, treated_outcome_true, outcome_before_treatment_nodes = (
# --> 264     self._find_outcomes(medrecord, treated_set)
#     265 )
#     266 treated_outcome_false = treated_set - treated_outcome_true
#     268 # Find the controls (patients that did not undergo the treatment)
#
# File ~/Desktop/projects/medmodels/medmodels/treatment_effect/treatment_effect.py:346, in TreatmentEffect._find_outcomes(self, medrecord, treated_set)
#     344 if not outcomes:
#     345     msg = f"No outcomes found in the MedRecord for group {self._outcomes_group}"
# --> 346     raise ValueError(msg)
#     348 if outcome_before_treatment_days and self._time_attribute:
#     349     outcome_before_treatment_nodes = set(
#     350         medrecord.select_nodes(
#     351             lambda node: self._query_node_within_time_window(
#    (...)    359         )
#     360     )
#
# ValueError: No outcomes found in the MedRecord for group dehydration

# %%
treatment_effect.report.full_report(medrecord)
# Out:
# {'relative_risk': 0.0,
#  'odds_ratio': 0.0,
#  'confounding_bias': 1.1280276816608996,
#  'absolute_risk_reduction': 0.11349693251533742,
#  'number_needed_to_treat': 8.81081081081081,
#  'hazard_ratio': 0.0}

# %%
list_of_heart_diagnoses = [
    "fibrillation",
    "thrombosis",
    "heart failure",
    "infarction",
    "heart disease",
]


nodes_heart_diagnoses = [medrecord.select_nodes(lambda node: node.attribute("description").contains(diagnosis)) for diagnosis in list_of_heart_diagnoses]
nodes_heart_diagnoses = [item for sublist in nodes_heart_diagnoses for item in sublist]

def query_warfarin_nodes(node: NodeOperand) -> None:
    description_nodes = node.attribute("description")
    description_nodes.lowercase()
    description_nodes.contains("warfarin")

medrecord.add_group(group="Warfarin", nodes=query_warfarin_nodes)
medrecord.add_group(group="Heart Affection", nodes=nodes_heart_diagnoses)

# %%
treatment_effect = (
    TreatmentEffect.builder()
    .with_treatment("Warfarin")
    .with_outcome("Heart Affection")
    .with_patients_group("patients")
    .with_time_attribute("time")
    .with_follow_up_period(days=365*100)
    .with_grace_period(days=60)
    .build()
)

# %%
contingency_table = treatment_effect.estimate.subject_counts(medrecord)
print(contingency_table)
# Out:
# -----------------------------------
#                    Outcome
# Group           True     False
# -----------------------------------
# Treated         0        289
# Control         396      4315
# -----------------------------------
